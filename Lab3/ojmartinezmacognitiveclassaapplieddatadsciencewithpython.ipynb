# %% [markdown]
# **Lab3**

# %% [markdown]
# **Linkedin**
# https://www.linkedin.com/in/oscar-mart%C3%ADnez-1ba717114/

# %% [markdown]
# **Python 101 for Data Science certificate**
# https://courses.cognitiveclass.ai/certificates/414b670ce986402cbc7c264d7c70166e

# %% [markdown]
# ![ojmartinezmacognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Analysis with Python** https://courses.cognitiveclass.ai/certificates/c30e49e506484addb3329d1409b3d336

# %% [markdown]
# ![ojmartinezmadataanalysiswithpoython.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Visualization with Python** https://courses.cognitiveclass.ai/certificates/12b877f89b85426686d387694453619b

# %% [markdown]
# ![ojmartinezmadatavisualizationwithpython.JPG](data:image/jpeg;base64,...)
